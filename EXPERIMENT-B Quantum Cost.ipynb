# %%
import numpy as np
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister
from qiskit import BasicAer, execute
from qiskit.quantum_info import *
q = QuantumRegister(4, 'q0')
c = ClassicalRegister(1, 'c0')
qc = QuantumCircuit(q, c)
qc.ccx(q[0], q[1], q[2])
qc.cx(q[3], q[1])
qc.h(q[3])
qc.ccx(q[3], q[2], q[1])
qc.measure(q[3],c[0])
qc.draw(output='mpl')

# %%
qc.count_ops()
# Out:
# OrderedDict([('ccx', 2), ('cx', 1), ('h', 1), ('measure', 1)])

# %%
from qiskit.transpiler import PassManager
from qiskit.transpiler.passes import Unroller

# decompose the circuit using the unroller using u3 and cx gates

pass_ = Unroller(['u3', 'cx'])
pm = PassManager(pass_)
new_circuit = pm.run(qc) 
new_circuit.draw(output='mpl')

# %%
new_circuit.count_ops()
# Out:
# OrderedDict([('u3', 19), ('cx', 13), ('measure', 1)])

# %% [raw]
# Cost = 19+13x10 = 149

# %%
q = QuantumRegister(3, 'q0')
c = ClassicalRegister(1, 'c0')
qc = QuantumCircuit(q, c)
qc.ccx(q[0], q[1], q[2])
qc.draw(output='mpl')

# %%
pass_ = Unroller(['u3', 'cx'])
pm = PassManager(pass_)
new_circuit = pm.run(qc) 
new_circuit.draw(output='mpl')

# %%
new_circuit.count_ops()

# %% [raw]
# Total cost of a CCX gate = 9+6x10=69
